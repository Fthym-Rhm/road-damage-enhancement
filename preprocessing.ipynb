# %%
import cv2
import matplotlib.pyplot as plt

video_file_path='IMG_5985.mov'
cap=cv2.VideoCapture(avi_file_path)

frame_width = int(cap.get(3))
frame_height = int(cap.get(4))

def plot_histogram(image,title):
    histogram=cv2.calcHist([image],[0],None,[256],[0,256])
    plt.figure()
    plt.title(title)
    plt.xlabel("Pixel value")
    plt.ylabel("frequency")
    plt.plot(histogram)
    plt.xlim([0,255])
    plt.show()
if not cap.isOpened():
    print("Video file is not opened")
else:
    frame_count =0
    while True:
        ret,frame=cap.read()
        if not ret:
            print("Can not recieve frame")
            break
        frame_count += 1
        if frame_count % 60 == 0:
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            filename = f"frame{frame_count}.jpg"
            cv2.imwrite(filename, gray)
            plot_histogram(gray,"histogram")
        cv2.imshow("Frame", frame)
        if cv2.waitKey(40) == ord('q'):
            break
    print(frame_count)
cap.release()
cv2.destroyAllWindows()
# Out:
# 213

# %%
import cv2
import numpy as np

img = cv2.imread("frame60.jpg") 
gray=gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Original Blur", img)
cv2.imshow("Gray image",gray)
cv2.waitKey(0)
cv2.destroyAllWindows()
