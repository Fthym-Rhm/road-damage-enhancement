# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read image from repository
image = cv2.imread("frame_19.jpg", cv2.IMREAD_GRAYSCALE)

# Mean filter
def apply_mean_filter(image, kernel_size=3):
    kernel = np.ones((kernel_size, kernel_size), np.float32) / (kernel_size**2)
    return cv2.filter2D(image, -1, kernel)

filtered = apply_mean_filter(image)

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')

plt.subplot(1,2,2)
plt.title("Mean Filtered Image")
plt.imshow(filtered, cmap='gray')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 13
#      10     kernel = np.ones((kernel_size, kernel_size), np.float32) / (kernel_size**2)
#      11     return cv2.filter2D(image, -1, kernel)
# ---> 13 filtered = apply_mean_filter(image)
#      15 plt.figure(figsize=(10,5))
#      17 plt.subplot(1,2,1)
#
# Cell In[4], line 11, in apply_mean_filter(image, kernel_size)
#       9 def apply_mean_filter(image, kernel_size=3):
#      10     kernel = np.ones((kernel_size, kernel_size), np.float32) / (kernel_size**2)
# ---> 11     return cv2.filter2D(image, -1, kernel)
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\filter.dispatch.cpp:1527: error: (-215:Assertion failed) !_src.empty() in function 'cv::filter2D'
